# %%
import numpy as np
import csv
data=r'C:\Users\MANOJ KUMAR\Desktop\Python\datsets\haberman.csv'
df=pd.read_csv(data)
print(df)

# the above snippet gives complete information about dataset like rows,columns,attributes
# Out:
#      Age  Op_year  axil_nodes  surv_status
# 0     30       64           1            1
# 1     30       62           3            1
# 2     30       65           0            1
# 3     31       59           2            1
# 4     31       65           4            1
# 5     33       58          10            1
# 6     33       60           0            1
# 7     34       59           0            2
# 8     34       66           9            2
# 9     34       58          30            1
# 10    34       60           1            1
# 11    34       61          10            1
# 12    34       67           7            1
# 13    34       60           0            1
# 14    35       64          13            1
# 15    35       63           0            1
# 16    36       60           1            1
# 17    36       69           0            1
# 18    37       60           0            1
# 19    37       63           0            1
# 20    37       58           0            1
# ...

# %%
print(df.max())
print(df.min())
print(df.describe())
sns.set_style("whitegrid")
fg=sns.FacetGrid(df,hue="surv_status",height=8)
fg.map(plt.scatter,"Age","Op_year","axil_nodes")
plt.legend()
plt.show() 

# getting the differentiation of target variables using legend
# Out:
# Age            83
# Op_year        69
# axil_nodes     52
# surv_status     2
# dtype: int64
# Age            30
# Op_year        58
# axil_nodes      0
# surv_status     1
# dtype: int64
#               Age     Op_year  axil_nodes  surv_status
# count  306.000000  306.000000  306.000000   306.000000
# mean    52.457516   62.852941    4.026144     1.264706
# std     10.803452    3.249405    7.189654     0.441899
# min     30.000000   58.000000    0.000000     1.000000
# 25%     44.000000   60.000000    0.000000     1.000000
# 50%     52.000000   63.000000    1.000000     1.000000
# 75%     60.750000   65.750000    4.000000     2.000000
# max     83.000000   69.000000   52.000000     2.000000

# %%
df.sort_values("Age")
print(df["Age"])
print("25th percentile")
res=0.25*306
print(res)
print(df.iloc[77]["Age"])

print("50th percentile")
res1=0.50*306
print(res1)
print(df.iloc[153]["Age"])

print("75th percentile")
res2=0.75*306
print(res2)
print(df.iloc[230]["Age"])

# caliculating 25,50 and 75 percentiles 
# using iloc getting the value of "res"
# Out:
# 0      30
# 1      30
# 2      30
# 3      31
# 4      31
# 5      33
# 6      33
# 7      34
# 8      34
# 9      34
# 10     34
# 11     34
# 12     34
# 13     34
# 14     35
# 15     35
# 16     36
# 17     36
# 18     37
# 19     37
# 20     37
# 21     37
# 22     37
# 23     37
# 24     38
# 25     38
# 26     38
# 27     38
# 28     38
# 29     38
#        ..
# 276    67
# 277    67
# 278    67
# 279    68
# 280    68
# 281    69
# 282    69
# 283    69
# 284    69
# 285    70
# 286    70
# 287    70
# 288    70
# 289    70
# 290    70
# 291    70
# 292    71
# 293    72
# 294    72
# 295    72
# 296    72
# 297    73
# 298    73
# 299    74
# 300    74
# 301    75
# 302    76
# 303    77
# 304    78
# 305    83
# Name: Age, Length: 306, dtype: int64
# 25th percentile
# 76.5
# 44
# 50th percentile
# 153.0
# 52
# 75th percentile
# 229.5
# 61

# %%
fg=sns.FacetGrid(df,hue="surv_status",height=8)
fg.map(sns.distplot,"Age")
plt.legend()
plt.show()
# Out:
# c:\users\manoj kumar\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fg=sns.FacetGrid(df,hue="surv_status",height=8)
fg.map(sns.distplot,"Op_year")
plt.legend()
plt.show()
# Out:
# c:\users\manoj kumar\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df=pd.read_csv(data)
fg=sns.FacetGrid(df,hue="surv_status",height=8)
fg.map(sns.distplot,"axil_nodes")
plt.legend()
plt.show()
# Out:
# c:\users\manoj kumar\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# computing pdf & cdf
counts,bin_edges=np.histogram(df["Age"],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf=np.cumsum(pdf)
print(cdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.05228758 0.08823529 0.1503268  0.17320261 0.17973856 0.13398693
#  0.13398693 0.05882353 0.02287582 0.00653595]
# [30.  35.3 40.6 45.9 51.2 56.5 61.8 67.1 72.4 77.7 83. ]
# [0.05228758 0.14052288 0.29084967 0.46405229 0.64379085 0.77777778
#  0.91176471 0.97058824 0.99346405 1.        ]

# %%
# computing pdf & cdf
counts,bin_edges=np.histogram(df["Op_year"],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf=np.cumsum(pdf)
print(cdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.20588235 0.09150327 0.08496732 0.0751634  0.09803922 0.10130719
#  0.09150327 0.09150327 0.08169935 0.07843137]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# [0.20588235 0.29738562 0.38235294 0.45751634 0.55555556 0.65686275
#  0.74836601 0.83986928 0.92156863 1.        ]

# %%
# computing pdf & cdf
counts,bin_edges=np.histogram(df["axil_nodes"],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf=np.cumsum(pdf)
print(cdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.77124183 0.09803922 0.05882353 0.02614379 0.02941176 0.00653595
#  0.00326797 0.         0.00326797 0.00326797]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]
# [0.77124183 0.86928105 0.92810458 0.95424837 0.98366013 0.99019608
#  0.99346405 0.99346405 0.99673203 1.        ]

# %%
fg=sns.FacetGrid(df,hue="surv_status",height=8)
fg.map(sns.distplot,"axil_nodes")
plt.legend()
# computing pdf & cdf
# counts and bin_edges are normally genrated by np.histogram
counts,bin_edges=np.histogram(df["Op_year"],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print("counts")   
print(counts)
print("bin_edges")
print(bin_edges)
cdf=np.cumsum(pdf)
print(cdf)
# plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# c:\users\manoj kumar\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [0.20588235 0.09150327 0.08496732 0.0751634  0.09803922 0.10130719
#  0.09150327 0.09150327 0.08169935 0.07843137]
# counts
# [0.18716578 0.08318479 0.07724302 0.06833036 0.08912656 0.09209745
#  0.08318479 0.08318479 0.07427213 0.07130125]
# bin_edges
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# [0.20588235 0.29738562 0.38235294 0.45751634 0.55555556 0.65686275
#  0.74836601 0.83986928 0.92156863 1.        ]

# %%
# the below line states the 25,50 and 75 percentile for Age and Surv_status after 5 years
sns.boxplot(x="surv_status",y="Age",data=df)
plt.show()

# %%
# the below line states the 25,50 and 75 percentile for Op_year and Surv_status after 5 years
sns.boxplot(x="surv_status",y="Op_year",data=df)
plt.show()

# %%
# the below line states the 25,50 and 75 percentile for axil_nodes and Surv_status after 5 years
sns.boxplot(x="surv_status",y="axil_nodes",data=df)
plt.show()

# %%
# the below line states combintion of both pdf and boxplots for axil_nodes and Surv_status after 5 years
sns.violinplot(x="surv_status",y="axil_nodes",data=df)
plt.show()
# Out:
# c:\users\manoj kumar\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# the below line states combintion of both pdf and boxplots for axil_nodes and Surv_status after 5 years
# it gives gausian curve which explains clear picture of plot
sns.violinplot(x="surv_status",y="Age",data=df)
plt.show()
# Out:
# c:\users\manoj kumar\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# the below line states combintion of both pdf and boxplots for axil_nodes and Surv_status after 5 years
sns.violinplot(x="surv_status",y="Op_year",data=df)
plt.show()
# Out:
# c:\users\manoj kumar\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print(df.head())
sns.pairplot(df,hue="surv_status",height=3, vars=["Age", "Op_year", "axil_nodes"])
plt.show()
#df.describe()
#df.isna().sum()
# Out:
#    Age  Op_year  axil_nodes  surv_status
# 0   30       64           1            1
# 1   30       62           3            1
# 2   30       65           0            1
# 3   31       59           2            1
# 4   31       65           4            1

# %%
# the below plot states the distribution of data for Op_year vs Age
plt.scatter(df['Age'],df['Op_year'], c = 'g')
plt.xlabel('Age')
plt.ylabel('Operation year')
plt.title('Operation year vs Age')
plt.show()

# %%
# the below plot states the distribution of data for Op_year vs Age
plt.scatter(df['Op_year'],df['axil_nodes'], c = 'g')
plt.xlabel('Op_year')
plt.ylabel('axil_nodes')
plt.title('Operation year vs axil_nodes')
plt.show()

# %%
# the below plot states the distribution of data for Op_year vs Age
plt.scatter(df['Age'],df['axil_nodes'], c = 'g')
plt.xlabel('Age')
plt.ylabel('axil_nodes')
plt.title('Age vs axil_nodes')
plt.show()

# %%
sns.set_style('whitegrid');
sns.FacetGrid(df, hue = 'surv_status', height = 5)\
   .map(plt.scatter, 'Age', 'axil_nodes')\
   .add_legend();
plt.show();

# %%
sns.set_style('whitegrid');
sns.FacetGrid(df, hue = 'surv_status', height = 5)\
   .map(plt.scatter, 'Age', 'Op_year')\
   .add_legend();
plt.show();

# %%
# important conclusions

# Axil_nodes is most important feature in this dataset, as who had Axil node >= 1 those are more likely to die.
# The patients who had axil nodes from 1 to 24 are the majority of patients who died.
# Patients within range of 45-65 and had axil node >= 1 are more likely to die.
# We can conclude that large number of operation were done in span of 7 years between 1960 and 1966
# we can observe that when axil_nodes is zero concentration of distribution is dense which infer high survival
# 1 is patient survival status and 2 is patient dead status
# the survival distribution was uncertain for op_year and age for operations between 1960 and 1966 !!
# Almost 80% of the patients have less than or equal to 5 positive lymph nodes.
